# %% [markdown]
# # HW5 MPNN
#
# ## Overview
#
# In this question, we will try the Graph Neural Network (GNN).

# %% [markdown]
# ---

# %%
import os
import pickle
import json
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# set seed
seed = 24
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)

# %%
import warnings
warnings.filterwarnings("ignore")

DATA_PATH = "data"

# %% [markdown]
# ---

# %% [markdown]
# We will use [PyTorch Geometric](https://pytorch-geometric.readthedocs.io/en/latest/index.html), which is a geometric deep learning extension library for PyTorch.

# %% [markdown]
# ## 1 Graph [10 points]
#
# First, let us learn the fundamental concepts of PyTorch Geometric.

# %% [markdown]
# A graph is used to model pairwise relations (edges) between objects (nodes).
# A single graph in PyTorch Geometric is described by an instance of `torch_geometric.data.Data`, which holds the following attributes by default:
#
# - `data.x`: Node feature matrix with shape `[num_nodes, num_node_features]`
# - `data.edge_index`: Graph connectivity in COO format with shape `[2, num_edges]` and type `torch.long`
# - `data.edge_attr`: Edge feature matrix with shape `[num_edges, num_edge_features]`
# - `data.y`: Target to train against (may have arbitrary shape), *e.g.*, node-level targets of shape `[num_nodes, *]` or graph-level targets of shape `[1, *]`
# - `data.pos`: Node position matrix with shape `[num_nodes, num_dimensions]`
#
# Note that none of these attributes is required.
#
# We show a simple example of an unweighted and undirected graph with three nodes and four edges. Each node contains exactly one feature:
#
# <img width="500" src="img/graph-1.png">

# %%
from torch_geometric.data import Data

edge_index = torch.tensor([[0, 1, 1, 2],
                           [1, 0, 2, 1]], dtype=torch.long)
x = torch.tensor([[-1], [0], [1]], dtype=torch.float)

data = Data(x=x, edge_index=edge_index)
print(data)
print("num_nodes:", data.num_nodes)
print("num_edges:", data.num_edges)
print("num_node_features:", data.num_node_features)
# Out:
# Data(x=[3, 1], edge_index=[2, 4])
# num_nodes: 3
# num_edges: 4
# num_node_features: 1

# %% [markdown]
# Note that although the graph has only two edges, we need to define four index tuples to account for both directions of a edge.
#
# Now, create a `torch_geometric.data.Data` instance for the following graph.
#
# <img width="250" src="img/graph-2.png">
#
# Assign the graph-level target $1$ to the graph.

# %%
"""
TODO: create a `torch_geometric.data.Data` instance for the graph above. Set the graph-level target to 1.
"""

data = None

edge_index = torch.tensor([[0, 0, 1, 2],
                           [1, 2, 3, 1]], dtype=torch.long)

y = torch.tensor([1], dtype=torch.float)

data = Data(edge_index=edge_index, y=y)

# %%
'''
AUTOGRADER CELL. DO NOT MODIFY THIS.
'''

assert data.num_nodes == 4
assert data.num_edges == 4
assert data.y == 1
assert data.num_node_features == 0
assert data.num_edge_features == 0

# %% [markdown]
# ## 2 Dataset [20 points]
#
# For this question, we will use the [MUTAG dataset](http://networkrepository.com/Mutag.php). Each graph in the dataset represents a chemical compound and graph labels represent their mutagenic effect on a specific gram negative bacterium. The dataset includes 188 graphs. Graph nodes have 7 labels and each graph is labelled as belonging to 1 of 2 classes.

# %%
from torch_geometric.datasets import TUDataset

# TUDataset(root='data', name='MUTAG')

dataset = TUDataset(root=DATA_PATH, name='MUTAG')
print("len:", len(dataset))
print("num_classes:", dataset.num_classes)
print("num_node_features:", dataset.num_node_features)
# Out:
# len: 188
# num_classes: 2
# num_node_features: 7
# Processing...
# Done!

# %% [markdown]
# Let us take one graph as an example.

# %%
data = dataset[0]
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Number of features: {data.num_node_features}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Contains isolated nodes: {data.contains_isolated_nodes()}')
print(f'Contains self-loops: {data.contains_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
# Out:
# Number of nodes: 17
# Number of edges: 38
# Number of features: 7
# Average node degree: 2.24
# Contains isolated nodes: False
# Contains self-loops: False
# Is undirected: True

# %% [markdown]
# We can see that the first graph in the dataset contains 17 nodes, each one having 7 features. There are 38/2 = 19 undirected edges and the graph is assigned to exactly one class. In addition, the data object is holding exactly one graph-level target.

# %%
def graph_stat(dataset):
    """
    TODO: calculate the statistics of the ENZYMES dataset.
    
    Outputs:
        min_num_nodes: min number of nodes
        max_num_nodes: max number of nodes
        mean_num_nodes: average number of nodes
        min_num_edges: min number of edges
        max_num_edges: max number of edges
        mean_num_edges: average number of edges
    """
    nodes_edges = [(data.num_nodes, data.num_edges) for data in dataset]
    num_nodes, num_edges = list(list(zip(*nodes_edges))[0]), list(list(zip(*nodes_edges))[1])
    min_num_nodes = min(num_nodes)
    max_num_nodes = max(num_nodes)
    mean_num_nodes = np.mean(num_nodes)
    min_num_edges = min(num_edges)
    max_num_edges = max(num_edges)
    mean_num_edges = np.mean(num_edges)
    
    return min_num_nodes, max_num_nodes, mean_num_nodes, \
            min_num_edges, max_num_edges, mean_num_edges

# %%
'''
AUTOGRADER CELL. DO NOT MODIFY THIS.
'''
assert np.allclose(graph_stat(dataset), (10, 28, 17.93, 20, 66, 39.58), atol=1e-2)

# %% [markdown]
# Neural networks are usually trained in a batch-wise fashion. PyTorch Geometric achieves parallelization over a mini-batch by creating sparse block diagonal adjacency matrices (defined by `edge_index`) and concatenating feature and target matrices in the node dimension. This composition allows differing number of nodes and edges over examples in one batch:
#
# $\begin{split}\mathbf{A} = \begin{bmatrix} \mathbf{A}_1 & & \\ & \ddots & \\ & & \mathbf{A}_n \end{bmatrix}, \qquad \mathbf{X} = \begin{bmatrix} \mathbf{X}_1 \\ \vdots \\ \mathbf{X}_n \end{bmatrix}, \qquad \mathbf{Y} = \begin{bmatrix} \mathbf{Y}_1 \\ \vdots \\ \mathbf{Y}_n \end{bmatrix}\end{split}$
#
# Luckily, PyTorch Geometric contains its own `torch_geometric.data.DataLoader`, which already takes care of this concatenation process. Let us learn about it in an example:

# %%
from torch_geometric.data import DataLoader

loader = DataLoader(dataset, batch_size=32, shuffle=True)

loader_iter = iter(loader)
batch = next(loader_iter)
print(batch)
print(batch.num_graphs)
# Out:
# DataBatch(edge_index=[2, 1260], x=[571, 7], edge_attr=[1260, 4], y=[32], batch=[571], ptr=[33])
# 32

# %% [markdown]
# That is, each batch contains $32$ graphs whose nodes and edges are stacked into one matrix.

# %% [markdown]
# Now, let us create a 80/20 train/test split, and load them into the dataloaders.

# %%
# shuffle
dataset = dataset.shuffle()
# split
split_idx = int(len(dataset) * 0.8)
train_dataset = dataset[:split_idx]
test_dataset = dataset[split_idx:]

print("len train:", len(train_dataset))
print("len test:", len(test_dataset))
# Out:
# len train: 150
# len test: 38

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32)

# %% [markdown]
# ## 3 Graph Neural Network [50 points]
#
# After learning about the fundamental concepts in PyTorch Geometric, let us try implement our first graph neural network.
#
# We will use a simple Graph Convolution Network (GCN) to assign each enzyme to one of the 6 EC top-level classes.
#
# For a high-level explanation on GCN, have a look at its [blog](http://tkipf.github.io/graph-convolutional-networks/) post.

# %% [markdown]
# We will first implement a GCN layer. A GCN layer is given an adjacency matrix $A\in\mathbb{R}^{N\times N}$ and a node feature matrix $X\in\mathbb{R}^{N\times D_{in}}$, where $N$ is the number of nodes and $D_{in}$ is the input dimension. The graph convolution network will calculate its output by:
#
# $$
# X' = \hat{D}^{-1/2}\hat{A}\hat{D}^{-1/2}X\Theta
# $$
#
# where $\hat{A}=A+I$ denotes the adjacency matrix with self-loop, $\hat{D}_{ii}=\sum_{j=0}^{N-1}A_{ij}$ is its diagonal degree matrix and $\Theta\in\mathbb{R}^{D_{in}\times D_{out}}$ is the model parameter.

# %%
import math
from torch_geometric.utils import to_dense_adj, add_self_loops

class GCNConv(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(GCNConv, self).__init__()
        self.theta = nn.Parameter(torch.FloatTensor(in_channels, out_channels))
        # Initialize the parameters.
        stdv = 1. / math.sqrt(out_channels)
        self.theta.data.uniform_(-stdv, stdv)
    
    def forward(self, x, edge_index):
        """
        TODO:
            1. Generate the adjacency matrix with self-loop \hat{A} using edge_index.
            2. Calculate the diagonal degree matrix \hat{D}.
            3. Calculate the output X' with torch.mm using the equation above.
        """

        num_nodes = x.shape[0]
        A = torch.sparse_coo_tensor(edge_index, torch.ones(edge_index.shape[1]), (num_nodes, num_nodes))
        A = A.to_dense()
        A_hat = A + torch.eye(num_nodes)
        
        A_sum = torch.sum(A_hat, dim=1)
        D = torch.pow(A_sum, -0.5)
        D[D == float('inf')] = 0.0
        D_hat_sqrt = torch.diag(D)
        
        first = torch.mm(torch.mm(D_hat_sqrt, A_hat), D_hat_sqrt)
        second = torch.mm(x, self.theta)
        
        ret = torch.mm(first, second)
        
        return ret

# %%
'''
AUTOGRADER CELL. DO NOT MODIFY THIS.
'''
# Out:
# '\nAUTOGRADER CELL. DO NOT MODIFY THIS.\n'

# %% [markdown]
# <img width="500" src="img/graph-3.png">
#
# The GCN will have the following steps:
#
# - Embed each node by performing multiple rounds of message passing
# - Aggregate node embeddings into a unified graph embedding (readout layer)
# - Train a final classifier on the graph embedding
#
#
# There exists multiple readout layers in literature, but the most common one is to simply take the average of node embeddings:
#
# $$
# \mathbf{x}_{\mathcal{G}} = \frac{1}{|\mathcal{V}|} \sum_{v \in \mathcal{V}} \mathcal{x}^{(L)}_v
# $$
#
# PyTorch Geometric provides this functionality via `torch_geometric.nn.global_mean_pool`.

# %%
# from torch_geometric.nn import GCNConv
from torch_geometric.nn import global_mean_pool

class GCN(torch.nn.Module):
    def __init__(self):
        super(GCN, self).__init__()
        """
        TODO:
            1. Define the first convolution layer using `GCNConv()`. Set `out_channels` to 64;
            2. Define the first activation layer using `nn.ReLU()`;
            3. Define the second convolution layer using `GCNConv()`. Set `out_channels` to 64;
            4. Define the second activation layer using `nn.ReLU()`;
            5. Define the third convolution layer using `GCNConv()`. Set `out_channels` to 64;
            6. Define the dropout layer using `nn.Dropout()`;
            7. Define the linear layer using `nn.Linear()`. Set `output_size` to 2.

        Note that for MUTAG dataset, the number of node features is 7, and the number of classes is 2.

        """
        
        self.gcn1 = GCNConv(in_channels=7, out_channels=64)
        self.a1 = nn.ReLU()
        self.gcn2 = GCNConv(in_channels=64, out_channels=64)
        self.a2 = nn.ReLU()
        self.gcn3 = GCNConv(in_channels=64, out_channels=64)
        self.dropout = nn.Dropout(p=0.4)
        self.linear = nn.Linear(in_features=64, out_features=2)

    def forward(self, x, edge_index, batch):
        """
        TODO:
            1. Pass the data through the frst convolution layer;
            2. Pass the data through the activation layer;
            3. Pass the data through the second convolution layer;
            4. Obtain the graph embeddings using the readout layer with `global_mean_pool()`;
            5. Pass the graph embeddgins through the dropout layer;
            6. Pass the graph embeddings through the linear layer.
            
        Arguments:
            x: [num_nodes, 7], node features
            edge_index: [2, num_edges], edges
            batch: [num_nodes], batch assignment vector which maps each node to its 
                   respective graph in the batch

        Outputs:
            probs: probabilities of shape (batch_size, 2)
        """
        x = self.gcn1(x, edge_index)
        x = self.a1(x)
        x = self.gcn2(x, edge_index)
        x = self.a2(x)
        x = self.gcn3(x, edge_index)
        x = global_mean_pool(x, batch)
        x = self.dropout(x)
        x = self.linear(x)
        
        probs = torch.nn.functional.softmax(x, dim=-1)
        
        return probs
        
        
        
GCN()
# Out:
# GCN(
#   (gcn1): GCNConv()
#   (a1): ReLU()
#   (gcn2): GCNConv()
#   (a2): ReLU()
#   (gcn3): GCNConv()
#   (dropout): Dropout(p=0.4, inplace=False)
#   (linear): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
'''
AUTOGRADER CELL. DO NOT MODIFY THIS.
'''
# Out:
# '\nAUTOGRADER CELL. DO NOT MODIFY THIS.\n'

# %%
'''
AUTOGRADER CELL. DO NOT MODIFY THIS.
'''
# Out:
# '\nAUTOGRADER CELL. DO NOT MODIFY THIS.\n'

# %% [markdown]
# ## 4 Training and Inferencing [20 points]
#
# Let us train our network for a few epochs to see how well it performs on the training as well as test set.

# %%
gcn = GCN()

# optimizer
optimizer = torch.optim.Adam(gcn.parameters(), lr=0.01)
# loss
criterion = torch.nn.CrossEntropyLoss()

def train(train_loader):
    gcn.train()
    for data in train_loader:  # Iterate in batches over the training dataset.
        """
        TODO: train the model for one epoch.
        
        Note that you can acess the batch data using `data.x`, `data.edge_index`, `data.batch`, `data,y`.
        """
        
        out = gcn(data.x, data.edge_index, data.batch)
        loss = criterion(out, data.y)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        
        
def test(loader):
    gcn.eval()
    correct = 0
    for data in loader:  # Iterate in batches over the training/test dataset.
        out = gcn(data.x, data.edge_index, data.batch)  
        pred = out.argmax(dim=1)  # Use the class with highest probability.
        correct += int((pred == data.y).sum())  # Check against ground-truth labels.
    return correct / len(loader.dataset)  # Derive ratio of correct predictions.


for epoch in range(200):
    train(train_loader)
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    print(f'Epoch: {epoch + 1:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# Epoch: 001, Train Acc: 0.6467, Test Acc: 0.7368
# Epoch: 002, Train Acc: 0.6467, Test Acc: 0.7368
# Epoch: 003, Train Acc: 0.6467, Test Acc: 0.7368
# Epoch: 004, Train Acc: 0.6467, Test Acc: 0.7368
# Epoch: 005, Train Acc: 0.6533, Test Acc: 0.7368
# Epoch: 006, Train Acc: 0.7400, Test Acc: 0.7895
# Epoch: 007, Train Acc: 0.7267, Test Acc: 0.7895
# Epoch: 008, Train Acc: 0.7267, Test Acc: 0.7895
# Epoch: 009, Train Acc: 0.7200, Test Acc: 0.7368
# Epoch: 010, Train Acc: 0.7400, Test Acc: 0.7895
# Epoch: 011, Train Acc: 0.7333, Test Acc: 0.7632
# Epoch: 012, Train Acc: 0.7400, Test Acc: 0.7632
# Epoch: 013, Train Acc: 0.7467, Test Acc: 0.8158
# Epoch: 014, Train Acc: 0.7467, Test Acc: 0.8158
# Epoch: 015, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 016, Train Acc: 0.7333, Test Acc: 0.8158
# Epoch: 017, Train Acc: 0.7467, Test Acc: 0.8158
# Epoch: 018, Train Acc: 0.7400, Test Acc: 0.7368
# Epoch: 019, Train Acc: 0.7600, Test Acc: 0.8158
# Epoch: 020, Train Acc: 0.6933, Test Acc: 0.7632
# Epoch: 021, Train Acc: 0.7400, Test Acc: 0.8158
# Epoch: 022, Train Acc: 0.7333, Test Acc: 0.7368
# Epoch: 023, Train Acc: 0.7400, Test Acc: 0.8158
# Epoch: 024, Train Acc: 0.7400, Test Acc: 0.8158
# Epoch: 025, Train Acc: 0.7533, Test Acc: 0.8158
# Epoch: 026, Train Acc: 0.7467, Test Acc: 0.8158
# Epoch: 027, Train Acc: 0.7467, Test Acc: 0.7632
# Epoch: 028, Train Acc: 0.7467, Test Acc: 0.7632
# Epoch: 029, Train Acc: 0.7400, Test Acc: 0.7632
# Epoch: 030, Train Acc: 0.7533, Test Acc: 0.7632
# Epoch: 031, Train Acc: 0.7533, Test Acc: 0.7632
# Epoch: 032, Train Acc: 0.7467, Test Acc: 0.7632
# Epoch: 033, Train Acc: 0.7467, Test Acc: 0.8158
# Epoch: 034, Train Acc: 0.7533, Test Acc: 0.7632
# Epoch: 035, Train Acc: 0.7667, Test Acc: 0.7632
# Epoch: 036, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 037, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 038, Train Acc: 0.7667, Test Acc: 0.7895
# Epoch: 039, Train Acc: 0.7533, Test Acc: 0.7895
# Epoch: 040, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 041, Train Acc: 0.7600, Test Acc: 0.7632
# Epoch: 042, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 043, Train Acc: 0.7533, Test Acc: 0.8158
# Epoch: 044, Train Acc: 0.7533, Test Acc: 0.8158
# Epoch: 045, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 046, Train Acc: 0.7533, Test Acc: 0.8158
# Epoch: 047, Train Acc: 0.7867, Test Acc: 0.7895
# Epoch: 048, Train Acc: 0.7867, Test Acc: 0.7895
# Epoch: 049, Train Acc: 0.7667, Test Acc: 0.7895
# Epoch: 050, Train Acc: 0.7867, Test Acc: 0.8158
# Epoch: 051, Train Acc: 0.7800, Test Acc: 0.8158
# Epoch: 052, Train Acc: 0.7867, Test Acc: 0.7895
# Epoch: 053, Train Acc: 0.7933, Test Acc: 0.7895
# Epoch: 054, Train Acc: 0.8000, Test Acc: 0.8158
# Epoch: 055, Train Acc: 0.7933, Test Acc: 0.7632
# Epoch: 056, Train Acc: 0.8133, Test Acc: 0.7895
# Epoch: 057, Train Acc: 0.8067, Test Acc: 0.7368
# Epoch: 058, Train Acc: 0.7733, Test Acc: 0.7895
# Epoch: 059, Train Acc: 0.8133, Test Acc: 0.7632
# Epoch: 060, Train Acc: 0.8200, Test Acc: 0.7368
# Epoch: 061, Train Acc: 0.7867, Test Acc: 0.7895
# Epoch: 062, Train Acc: 0.7800, Test Acc: 0.7632
# Epoch: 063, Train Acc: 0.8067, Test Acc: 0.7632
# Epoch: 064, Train Acc: 0.7533, Test Acc: 0.7895
# Epoch: 065, Train Acc: 0.7667, Test Acc: 0.8158
# Epoch: 066, Train Acc: 0.7800, Test Acc: 0.8158
# Epoch: 067, Train Acc: 0.7867, Test Acc: 0.7895
# Epoch: 068, Train Acc: 0.8000, Test Acc: 0.7632
# Epoch: 069, Train Acc: 0.7933, Test Acc: 0.7895
# Epoch: 070, Train Acc: 0.8200, Test Acc: 0.7368
# Epoch: 071, Train Acc: 0.8200, Test Acc: 0.7368
# Epoch: 072, Train Acc: 0.8067, Test Acc: 0.7895
# Epoch: 073, Train Acc: 0.8200, Test Acc: 0.7368
# Epoch: 074, Train Acc: 0.8267, Test Acc: 0.7368
# Epoch: 075, Train Acc: 0.7867, Test Acc: 0.8158
# Epoch: 076, Train Acc: 0.8000, Test Acc: 0.7632
# Epoch: 077, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 078, Train Acc: 0.7867, Test Acc: 0.7895
# Epoch: 079, Train Acc: 0.7867, Test Acc: 0.7895
# Epoch: 080, Train Acc: 0.8133, Test Acc: 0.7895
# Epoch: 081, Train Acc: 0.8067, Test Acc: 0.7632
# Epoch: 082, Train Acc: 0.8133, Test Acc: 0.7632
# Epoch: 083, Train Acc: 0.8200, Test Acc: 0.7632
# Epoch: 084, Train Acc: 0.8067, Test Acc: 0.7368
# Epoch: 085, Train Acc: 0.8067, Test Acc: 0.7632
# Epoch: 086, Train Acc: 0.8267, Test Acc: 0.7368
# Epoch: 087, Train Acc: 0.8133, Test Acc: 0.7632
# Epoch: 088, Train Acc: 0.7867, Test Acc: 0.7895
# Epoch: 089, Train Acc: 0.8200, Test Acc: 0.7632
# Epoch: 090, Train Acc: 0.8333, Test Acc: 0.7632
# Epoch: 091, Train Acc: 0.8133, Test Acc: 0.7895
# Epoch: 092, Train Acc: 0.8400, Test Acc: 0.7368
# Epoch: 093, Train Acc: 0.8200, Test Acc: 0.7632
# Epoch: 094, Train Acc: 0.8067, Test Acc: 0.7895
# Epoch: 095, Train Acc: 0.8133, Test Acc: 0.7368
# Epoch: 096, Train Acc: 0.8267, Test Acc: 0.7895
# Epoch: 097, Train Acc: 0.8267, Test Acc: 0.7632
# Epoch: 098, Train Acc: 0.8133, Test Acc: 0.7895
# Epoch: 099, Train Acc: 0.7933, Test Acc: 0.8158
# Epoch: 100, Train Acc: 0.8200, Test Acc: 0.7895
# Epoch: 101, Train Acc: 0.7400, Test Acc: 0.6842
# Epoch: 102, Train Acc: 0.8000, Test Acc: 0.7632
# Epoch: 103, Train Acc: 0.8000, Test Acc: 0.7895
# Epoch: 104, Train Acc: 0.8133, Test Acc: 0.7895
# Epoch: 105, Train Acc: 0.8133, Test Acc: 0.7632
# Epoch: 106, Train Acc: 0.8067, Test Acc: 0.7368
# Epoch: 107, Train Acc: 0.8267, Test Acc: 0.7632
# Epoch: 108, Train Acc: 0.8467, Test Acc: 0.7895
# Epoch: 109, Train Acc: 0.8200, Test Acc: 0.7632
# Epoch: 110, Train Acc: 0.8200, Test Acc: 0.7895
# Epoch: 111, Train Acc: 0.8333, Test Acc: 0.7632
# Epoch: 112, Train Acc: 0.8533, Test Acc: 0.7895
# Epoch: 113, Train Acc: 0.8533, Test Acc: 0.7895
# Epoch: 114, Train Acc: 0.8400, Test Acc: 0.7632
# Epoch: 115, Train Acc: 0.8467, Test Acc: 0.7895
# Epoch: 116, Train Acc: 0.8533, Test Acc: 0.7632
# Epoch: 117, Train Acc: 0.8267, Test Acc: 0.8158
# Epoch: 118, Train Acc: 0.8533, Test Acc: 0.7632
# Epoch: 119, Train Acc: 0.8600, Test Acc: 0.7895
# Epoch: 120, Train Acc: 0.8533, Test Acc: 0.7895
# Epoch: 121, Train Acc: 0.8267, Test Acc: 0.7895
# Epoch: 122, Train Acc: 0.8467, Test Acc: 0.7632
# Epoch: 123, Train Acc: 0.8600, Test Acc: 0.7895
# Epoch: 124, Train Acc: 0.8267, Test Acc: 0.7895
# Epoch: 125, Train Acc: 0.8600, Test Acc: 0.7895
# Epoch: 126, Train Acc: 0.8467, Test Acc: 0.7632
# Epoch: 127, Train Acc: 0.8400, Test Acc: 0.7895
# Epoch: 128, Train Acc: 0.8600, Test Acc: 0.7895
# Epoch: 129, Train Acc: 0.8667, Test Acc: 0.8158
# Epoch: 130, Train Acc: 0.8600, Test Acc: 0.7895
# Epoch: 131, Train Acc: 0.8533, Test Acc: 0.7632
# Epoch: 132, Train Acc: 0.8600, Test Acc: 0.7632
# Epoch: 133, Train Acc: 0.8533, Test Acc: 0.7895
# Epoch: 134, Train Acc: 0.8333, Test Acc: 0.7632
# Epoch: 135, Train Acc: 0.8200, Test Acc: 0.7895
# Epoch: 136, Train Acc: 0.8600, Test Acc: 0.7895
# Epoch: 137, Train Acc: 0.8600, Test Acc: 0.7895
# Epoch: 138, Train Acc: 0.8200, Test Acc: 0.7632
# Epoch: 139, Train Acc: 0.8667, Test Acc: 0.8158
# Epoch: 140, Train Acc: 0.8533, Test Acc: 0.7895
# Epoch: 141, Train Acc: 0.8333, Test Acc: 0.7895
# Epoch: 142, Train Acc: 0.8533, Test Acc: 0.8158
# Epoch: 143, Train Acc: 0.8467, Test Acc: 0.7895
# Epoch: 144, Train Acc: 0.8600, Test Acc: 0.8158
# Epoch: 145, Train Acc: 0.8467, Test Acc: 0.7632
# Epoch: 146, Train Acc: 0.8667, Test Acc: 0.7895
# Epoch: 147, Train Acc: 0.8600, Test Acc: 0.7895
# Epoch: 148, Train Acc: 0.8667, Test Acc: 0.7895
# Epoch: 149, Train Acc: 0.8533, Test Acc: 0.7895
# Epoch: 150, Train Acc: 0.8600, Test Acc: 0.7895
# Epoch: 151, Train Acc: 0.8600, Test Acc: 0.7895
# Epoch: 152, Train Acc: 0.8667, Test Acc: 0.7895
# Epoch: 153, Train Acc: 0.8667, Test Acc: 0.7895
# Epoch: 154, Train Acc: 0.8600, Test Acc: 0.7895
# Epoch: 155, Train Acc: 0.8667, Test Acc: 0.7895
# Epoch: 156, Train Acc: 0.8667, Test Acc: 0.7895
# Epoch: 157, Train Acc: 0.8600, Test Acc: 0.7895
# Epoch: 158, Train Acc: 0.8533, Test Acc: 0.7895
# Epoch: 159, Train Acc: 0.8533, Test Acc: 0.7895
# Epoch: 160, Train Acc: 0.8667, Test Acc: 0.7895
# Epoch: 161, Train Acc: 0.8533, Test Acc: 0.7632
# Epoch: 162, Train Acc: 0.8600, Test Acc: 0.7895
# Epoch: 163, Train Acc: 0.8667, Test Acc: 0.8158
# Epoch: 164, Train Acc: 0.8533, Test Acc: 0.8158
# Epoch: 165, Train Acc: 0.8533, Test Acc: 0.7895
# Epoch: 166, Train Acc: 0.8533, Test Acc: 0.7895
# Epoch: 167, Train Acc: 0.8533, Test Acc: 0.7895
# Epoch: 168, Train Acc: 0.8467, Test Acc: 0.8158
# Epoch: 169, Train Acc: 0.8667, Test Acc: 0.7895
# Epoch: 170, Train Acc: 0.8667, Test Acc: 0.7895
# Epoch: 171, Train Acc: 0.8667, Test Acc: 0.7895
# Epoch: 172, Train Acc: 0.8267, Test Acc: 0.7895
# Epoch: 173, Train Acc: 0.7467, Test Acc: 0.7105
# Epoch: 174, Train Acc: 0.7733, Test Acc: 0.7632
# Epoch: 175, Train Acc: 0.8067, Test Acc: 0.8158
# Epoch: 176, Train Acc: 0.8200, Test Acc: 0.7895
# Epoch: 177, Train Acc: 0.7867, Test Acc: 0.7632
# Epoch: 178, Train Acc: 0.8267, Test Acc: 0.7368
# Epoch: 179, Train Acc: 0.8600, Test Acc: 0.7895
# Epoch: 180, Train Acc: 0.8267, Test Acc: 0.7632
# Epoch: 181, Train Acc: 0.8533, Test Acc: 0.8158
# Epoch: 182, Train Acc: 0.8533, Test Acc: 0.7895
# Epoch: 183, Train Acc: 0.8333, Test Acc: 0.8158
# Epoch: 184, Train Acc: 0.8267, Test Acc: 0.7895
# Epoch: 185, Train Acc: 0.8267, Test Acc: 0.7895
# Epoch: 186, Train Acc: 0.8467, Test Acc: 0.7895
# Epoch: 187, Train Acc: 0.8000, Test Acc: 0.7895
# Epoch: 188, Train Acc: 0.8133, Test Acc: 0.8158
# Epoch: 189, Train Acc: 0.8267, Test Acc: 0.7632
# Epoch: 190, Train Acc: 0.8267, Test Acc: 0.7632
# Epoch: 191, Train Acc: 0.8667, Test Acc: 0.7895
# Epoch: 192, Train Acc: 0.8733, Test Acc: 0.7895
# Epoch: 193, Train Acc: 0.8533, Test Acc: 0.7632
# Epoch: 194, Train Acc: 0.8467, Test Acc: 0.7895
# Epoch: 195, Train Acc: 0.8667, Test Acc: 0.7895
# Epoch: 196, Train Acc: 0.8600, Test Acc: 0.7895
# Epoch: 197, Train Acc: 0.8600, Test Acc: 0.7895
# Epoch: 198, Train Acc: 0.8600, Test Acc: 0.7895
# Epoch: 199, Train Acc: 0.8667, Test Acc: 0.7895
# Epoch: 200, Train Acc: 0.8600, Test Acc: 0.7895

# %%
'''
AUTOGRADER CELL. DO NOT MODIFY THIS.
'''

test_acc = test(test_loader)

# %%
test_acc
# Out:
# 0.7894736842105263
